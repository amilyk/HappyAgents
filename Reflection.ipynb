# %% [markdown]
# <a href="https://colab.research.google.com/github/amilyk/HappyAgents/blob/main/Reflection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !touch .env
# !echo "LLM_API_KEY='你自己的apikey，比如zhipu'" >> .env
# !echo "LLM_MODEL_ID='glm-4'" >> .env
# !echo "LLM_BASE_URL='https://open.bigmodel.cn/api/paas/v4'" >> .env

# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %% [markdown]
# # 记忆模块（尝试和反馈）

# %%
from typing import List, Dict, Any, Optional

class Memory:
    """
    一个简单的短期记忆模块，用于存储智能体的行动Execution与反思Reflection轨迹。
    """

    def __init__(self):
        """
        初始化一个空列表来存储所有记录。
        """
        self.records: List[Dict[str, Any]] = []

    def add_record(self, record_type: str, content: str):
        """
        向记忆中添加一条新记录。

        参数:
        - record_type (str): 记录的类型 ('execution' 或 'reflection')。
        - content (str): 记录的具体内容 (例如，生成的代码或反思的反馈)。
        """
        record = {"type": record_type, "content": content}
        self.records.append(record)
        print(f"📝 记忆已更新，新增一条 '{record_type}' 记录。")

    def get_trajectory(self) -> str:
        """
        将所有记忆记录格式化为一个连贯的字符串文本，用于构建提示词。
        """
        trajectory_parts = []
        for record in self.records:
            if record['type'] == 'execution':
                trajectory_parts.append(f"--- 上一轮尝试 (代码) ---\n{record['content']}")
            elif record['type'] == 'reflection':
                trajectory_parts.append(f"--- 评审员反馈 ---\n{record['content']}")

        return "\n\n".join(trajectory_parts)

    def get_last_execution(self) -> Optional[str]:
        """
        获取最近一次的执行结果 (例如，最新生成的代码)。
        如果不存在，则返回 None。
        """
        for record in reversed(self.records):
            if record['type'] == 'execution':
                return record['content']
        return None

# %% [markdown]
# # 初始记忆提示词

# %%
INITIAL_PROMPT_TEMPLATE = """
你是一位资深的Python程序员。请根据以下要求，编写一个Python函数。
你的代码必须包含完整的函数签名、文档字符串，并遵循PEP 8编码规范。

要求: {task}

请直接输出代码，不要包含任何额外的解释。
"""

# %% [markdown]
# # 反思提示词

# %%
REFLECT_PROMPT_TEMPLATE = """
你是一位极其严格的代码评审专家和资深算法工程师，对代码的性能有极致的要求。
你的任务是审查以下Python代码，并专注于找出其在<strong>算法效率</strong>上的主要瓶颈。

# 原始任务:
{task}

# 待审查的代码:
```python
{code}
```

请分析该代码的时间复杂度，并思考是否存在一种<strong>算法上更优</strong>的解决方案来显著提升性能。
如果存在，请清晰地指出当前算法的不足，并提出具体的、可行的改进算法建议（例如，使用筛法替代试除法）。
如果代码在算法层面已经达到最优，才能回答“无需改进”。

请直接输出你的反馈，不要包含任何额外的解释。
"""

# %% [markdown]
# # 优化提示词

# %%
REFINE_PROMPT_TEMPLATE = """
你是一位资深的Python程序员。你正在根据一位代码评审专家的反馈来优化你的代码。

# 原始任务:
{task}

# 你上一轮尝试的代码:
```
{last_code_attempt}
评审员的反馈：
{feedback}

请根据评审员的反馈，生成一个优化后的新版本代码。
你的代码必须包含完整的函数签名、文档字符串，并遵循PEP 8编码规范。
请直接输出优化后的代码，不要包含任何额外的解释。
"""

# %% [markdown]
# # 通用LLM客户端

# %%
# import os
from openai import OpenAI
from typing import List, Dict

# 加载 .env 文件中的环境变量
# load_dotenv()

class HelloAgentsLLM:
    """
    为本书 "Hello Agents" 定制的LLM客户端。
    它用于调用任何兼容OpenAI接口的服务，并默认使用流式响应。
    """
    def __init__(self, model: str = None, apiKey: str = None, baseUrl: str = None, timeout: int = None):
        """
        初始化客户端。优先使用传入参数，如果未提供，则从环境变量加载。
        """
        self.model = model or os.environ.get("LLM_MODEL_ID")
        apiKey = apiKey or os.environ.get("LLM_API_KEY")
        baseUrl = baseUrl or os.environ.get("LLM_BASE_URL")
        timeout = timeout or int(os.environ.get("LLM_TIMEOUT", 60))

        if not all([self.model, apiKey, baseUrl]):
            raise ValueError("模型ID、API密钥和服务地址必须被提供或在.env文件中定义。")

        self.client = OpenAI(api_key=apiKey, base_url=baseUrl, timeout=timeout)

    def think(self, messages: List[Dict[str, str]], temperature: float = 0) -> str:
        """
        调用大语言模型进行思考，并返回其响应。
        """
        print(f"🧠 正在调用 {self.model} 模型...")
        try:
            response = self.client.chat.completions.create(
                model=self.model,
                messages=messages,
                temperature=temperature,
                stream=True,
            )

            # 处理流式响应
            print("✅ 大语言模型响应成功:")
            collected_content = []
            for chunk in response:
                content = chunk.choices[0].delta.content or ""
                print(content, end="", flush=True)
                collected_content.append(content)
            print()  # 在流式输出结束后换行
            return "".join(collected_content)

        except Exception as e:
            print(f"❌ 调用LLM API时发生错误: {e}")
            return None

# --- 客户端使用示例 ---
# if __name__ == '__main__':
#     try:
#         llmClient = HelloAgentsLLM()

#         exampleMessages = [
#             {"role": "system", "content": "You are a helpful assistant that writes Python code."},
#             {"role": "user", "content": "写一个快速排序算法"}
#         ]

#         print("--- 调用LLM ---")
#         responseText = llmClient.think(exampleMessages)
#         if responseText:
#             print("\n\n--- 完整模型响应 ---")
#             print(responseText)

#     except ValueError as e:
#         print(e)


# >>>
# --- 调用LLM ---
# 🧠 正在调用 xxxxxx 模型...
# ✅ 大语言模型响应成功:
# 快速排序是一种非常高效的排序算法...

# %% [markdown]
# # Reflection智能体

# %%
# 假设 llm_client.py 和 memory.py 已定义
# from llm_client import HelloAgentsLLM
# from memory import Memory

class ReflectionAgent:
    def __init__(self, llm_client, max_iterations=3):
        self.llm_client = llm_client
        self.memory = Memory()
        self.max_iterations = max_iterations

    def run(self, task: str):
        print(f"\n--- 开始处理任务 ---\n任务: {task}")

        # --- 1. 初始执行 ---
        print("\n--- 正在进行初始尝试 ---")
        initial_prompt = INITIAL_PROMPT_TEMPLATE.format(task=task)
        initial_code = self._get_llm_response(initial_prompt)
        self.memory.add_record("execution", initial_code)

        # --- 2. 迭代循环:反思与优化 ---
        for i in range(self.max_iterations):
            print(f"\n--- 第 {i+1}/{self.max_iterations} 轮迭代 ---")

            # a. 反思
            print("\n-> 正在进行反思...")
            last_code = self.memory.get_last_execution()
            reflect_prompt = REFLECT_PROMPT_TEMPLATE.format(task=task, code=last_code)
            feedback = self._get_llm_response(reflect_prompt)
            self.memory.add_record("reflection", feedback)

            # b. 检查是否需要停止
            if "无需改进" in feedback:
                print("\n✅ 反思认为代码已无需改进，任务完成。")
                break

            # c. 优化
            print("\n-> 正在进行优化...")
            refine_prompt = REFINE_PROMPT_TEMPLATE.format(
                task=task,
                last_code_attempt=last_code,
                feedback=feedback
            )
            refined_code = self._get_llm_response(refine_prompt)
            self.memory.add_record("execution", refined_code)

        final_code = self.memory.get_last_execution()
        print(f"\n--- 任务完成 ---\n最终生成的代码:\n```python\n{final_code}\n```")
        return final_code

    def _get_llm_response(self, prompt: str) -> str:
        """一个辅助方法，用于调用LLM并获取完整的流式响应。"""
        messages = [{"role": "user", "content": prompt}]
        response_text = self.llm_client.think(messages=messages) or ""
        return response_text

# %% [markdown]
# # 智能体调用

# %%
#调用Execution这里，只用了简单的LLM，其实还可以加上ReAct或者Plan and Solve做的更细致
if __name__ == "__main__":
  llm = HelloAgentsLLM()
  reflectionAgent = ReflectionAgent(llm)
  query = "编写一个Python函数，找出1到n之间所有的素数 (prime numbers)。"
  reflectionAgent.run(query)
# Out:
# --- 开始处理任务 ---
# 任务: 编写一个Python函数，找出1到n之间所有的素数 (prime numbers)。
#
# --- 正在进行初始尝试 ---
# 🧠 正在调用 glm-4 模型...
# ✅ 大语言模型响应成功:
# 以下是符合要求的Python函数：
#
# ```python
# def find_primes(n):
#     """
#     Find all prime numbers between 1 and n.
#
#     Parameters:
#     n (int): The upper limit to search for prime numbers.
#
#     Returns:
#     list: A list of prime numbers between 1 and n.
#     """
#     if n < 2:
#         return []
#
#     # Initialize a list to keep track of prime numbers
#     primes = []
#     # Create a boolean array "is_prime[0..n]" and initialize all entries as True.
#     # A value in is_prime[i] will be False if i is Not a prime, else True bool val.
#     is_prime = [True for _ in range(n+1)]
#     p = 2  # The first prime number is 2
#
#     while p * p <= n:
#         # If is_prime[p] is not changed, then it is a prime
#         if is_prime[p]:
#             # Update all multiples of p as not prime
#             for i in range(p * p, n+1, p):
#                 is_prime[i] = False
#         p += 1
#
#     # Collect all prime numbers into the list
#     for p in range(2, n+1):
#         if is_prime[p]:
#             primes.append(p)
#
#     return primes
# ```
#
# 该函数使用了埃拉托斯特尼筛法（Sieve of Eratosthenes）来找出1到n之间的所有素数。
# 📝 记忆已更新，新增一条 'execution' 记录。
#
# --- 第 1/3 轮迭代 ---
#
# -> 正在进行反思...
# 🧠 正在调用 glm-4 模型...
# ✅ 大语言模型响应成功:
# 该代码使用了埃拉托斯特尼筛法，其时间复杂度大致为 O(n log log n)，这是在处理范围内所有数字时相对高效的算法。主要的时间消耗在于两个嵌套循环：外层循环遍历所有可能的素数，内层循环标记所有该素数的倍数为非素数。
#
# 以下是几点关于算法效率的审查反馈：
#
# 1. **不必要的初始化**：`is_prime` 数组初始化为 `True` 的长度为 `n+1`，但实际上只需要到 `n` 即可，因为 `n` 本身不是素数。
#
#    **改进**：将 `is_prime = [True for _ in range(n+1)]` 改为 `is_prime = [True for _ in range(n)]`。
#
# 2. **内部循环的起始点**：内部循环从 `p * p` 开始标记，这是正确的。但是，由于所有小于 `p` 的素数已经将它们更小的倍数标记为非素数，因此可以减少迭代次数。
#
#    **改进**：对于每个素数 `p`，仅需要考虑从 `p * p` 开始，到 `n` 结束，但是可以跳过那些已经被更小素数标记为非素数的倍数。
#
# 3. **收集素数的循环**：在确定了所有非素数之后，代码通过遍历 `is_prime` 数组来收集所有素数。这个步骤是必要的，但是可以通过在筛除过程中直接添加素数到 `primes` 列表中来优化。
#
#    **改进**：在确定 `is_prime[p]` 为 `True` 时，直接添加 `p` 到 `primes` 列表，避免最后的遍历。
#
# 4. **算法优化**：尽管埃拉托斯特尼筛法已经相对高效，但对于非常大的 `n`，可以考虑使用分段筛法（Segmented Sieve），特别是当内存有限时。
#
#    **改进**：对于非常大的 `n`，可以采用分段筛法，只保留一段固定大小的素数候选列表，从而减少内存使用。
#
# 综上所述，代码在算法效率上已经相对较好，但仍有改进空间。对于小到中等规模的 `n`，当前的实现已经足够高效，但如果要处理非常大的 `n`，可以考虑上述建议进行优化。
# 📝 记忆已更新，新增一条 'reflection' 记录。
#
# -> 正在进行优化...
# 🧠 正在调用 glm-4 模型...
# ✅ 大语言模型响应成功:
# ```python
# def find_primes(n):
#     """
#     Find all prime numbers between 1 and n.
#
#     Parameters:
#     n (int): The upper limit to search for prime numbers.
#
#     Returns:
#     list: A list of prime numbers between 1 and n.
#     """
#     if n < 2:
#         return []
#
#     # Initialize a list to keep track of prime numbers
#     primes = []
#     # Create a boolean array "is_prime[0..n-1]" and initialize all entries as True.
#     is_prime = [True] * n
#     p = 2  # The first prime number is 2
#
#     while p * p <= n:
#         # If is_prime[p] is not changed, then it is a prime
#         if is_prime[p]:
#             # Add prime number to the list
#             primes.append(p)
#             # Update all multiples of p as not prime starting from p * p
#             for i in range(p * p, n, p):
#                 is_prime[i] = False
#         p += 1
#
#     # Add remaining primes greater than sqrt(n) to the list
#     for p in range(int(n**0.5) + 1, n):
#         if is_prime[p]:
#             primes.append(p)
#
#     return primes
# ```
# 📝 记忆已更新，新增一条 'execution' 记录。
#
# --- 第 2/3 轮迭代 ---
#
# -> 正在进行反思...
# 🧠 正在调用 glm-4 模型...
# ✅ 大语言模型响应成功:
# 当前代码使用的是试除法（Trial Division）来找出所有素数，其时间复杂度主要取决于以下两个循环：
#
# 1. 第一个 `while` 循环的时间复杂度是 O(n log log n)，因为它迭代到 `sqrt(n)`，并且每次迭代会检查并更新数组 `is_prime` 中的元素，其更新操作的数量与 `p` 的倍数相关，平均而言，每个素数 `p` 会检查大约 `n/p` 个元素。
#
# 2. 第二个 `for` 循环的时间复杂度是 O(n - sqrt(n))，即 O(n)，因为它检查并添加剩余的素数到列表中。
#
# 综合来看，总的时间复杂度接近 O(n log log n)。
#
# **算法瓶颈与改进建议：**
#
# - **埃拉托斯特尼筛法（Sieve of Eratosthenes）未充分利用：** 当前代码在实现上类似于筛法，但未充分利用筛法的优势。筛法可以通过仅标记非素数的倍数来避免不必要的迭代。
#
# - **不必要的二次检查：** 第二个 `for` 循环检查了从 `sqrt(n)` 到 `n-1` 的所有数字，但实际上，如果 `p` 是素数，那么 `p` 的所有倍数在第一个 `while` 循环中已经被标记为非素数。
#
# **改进算法建议：**
#
# 1. 使用正宗的埃拉托斯特尼筛法，仅迭代到 `sqrt(n)`，并确保每个合数只被其最小质因数标记一次。
#
# 2. 移除第二个 `for` 循环，因为在第一个 `while` 循环结束后，所有未被标记为非素数的数字都是素数。
#
# 以下是改进后的代码示例：
#
# ```python
# def find_primes(n):
#     if n < 2:
#         return []
#
#     primes = []
#     is_prime = [True] * (n + 1)  # 增加一个额外的空间以简化逻辑
#     is_prime[0], is_prime[1] = False, False  # 0 和 1 不是素数
#
#     for p in range(2, int(n**0.5) + 1):
#         if is_prime[p]:
#             primes.append(p)
#             for i in range(p * p, n + 1, p):  # 直接从 p^2 开始，到 n 结束
#                 is_prime[i] = False
#
#     # 直接返回剩余的素数，无需额外循环
#     return primes + [p for p in range(int(n**0.5) + 1, n + 1) if is_prime[p]]
# ```
#
# 这种改进将显著减少不必要的迭代次数，并使算法更加接近 O(n log log n) 的时间复杂度。
# 📝 记忆已更新，新增一条 'reflection' 记录。
#
# -> 正在进行优化...
# 🧠 正在调用 glm-4 模型...
# ✅ 大语言模型响应成功:
# ```python
# def find_primes(n):
#     """
#     Find all prime numbers between 1 and n.
#
#     Parameters:
#     n (int): The upper limit to search for prime numbers.
#
#     Returns:
#     list: A list of prime numbers between 1 and n.
#     """
#     if n < 2:
#         return []
#
#     primes = []
#     is_prime = [True] * (n + 1)
#     is_prime[0], is_prime[1] = False, False
#
#     for p in range(2, int(n**0.5) + 1):
#         if is_prime[p]:
#             primes.append(p)
#             for i in range(p * p, n + 1, p):
#                 is_prime[i] = False
#
#     return primes + [p for p in range(int(n**0.5) + 1, n + 1) if is_prime[p]]
# ```
# 📝 记忆已更新，新增一条 'execution' 记录。
#
# --- 第 3/3 轮迭代 ---
#
# -> 正在进行反思...
# 🧠 正在调用 glm-4 模型...
# ✅ 大语言模型响应成功:
# 当前代码的时间复杂度主要取决于两部分：
#
# 1. 外层循环遍历从2到sqrt(n)，以找出所有的质数，这个操作的时间复杂度是O(sqrt(n))。
# 2. 内层循环对每个质数p，将p的倍数标记为非质数，这部分的时间复杂度是O(n)。
#
# 由于内层循环的复杂度高于外层循环，因此总的时间复杂度是O(n)。
#
# 主要瓶颈：
# - 对每个质数p，内层循环需要遍历从p^2到n的所有p的倍数，这是不必要的，因为小于p的质数的倍数在之前已经被标记了。
#
# 改进建议：
# - 使用埃拉托斯特尼筛法（Sieve of Eratosthenes），在内层循环中仅需要遍历到n/p，而不是n，因为大于n/p的倍数在之前已经被更小的质数标记了。
# - 可以进一步优化，在内层循环中仅考虑质数倍数，即仅对那些未被更小质数标记的数进行操作。
#
# 以下是优化后的代码示例：
#
# ```python
# def find_primes(n):
#     if n < 2:
#         return []
#
#     is_prime = [True] * (n + 1)
#     is_prime[0], is_prime[1] = False, False
#     primes = []
#
#     for p in range(2, int(n**0.5) + 1):
#         if is_prime[p]:
#             primes.append(p)
#             # 只需要遍历到 n/p，且只对质数倍数进行操作
#             for i in range(p * p, n + 1, p):
#                 if is_prime[i]:
#                     is_prime[i] = False
#
#     # 只收集质数
#     return primes + [p for p in range(int(n**0.5) + 1, n + 1) if is_prime[p]]
# ```
#
# 这样，内层循环的时间复杂度从O(n)降低到O(n/log(n))，因此整体算法的时间复杂度将接近O(n log log(n))，这是一个显著的性能提升。
# 📝 记忆已更新，新增一条 'reflection' 记录。
#
# -> 正在进行优化...
# 🧠 正在调用 glm-4 模型...
# ✅ 大语言模型响应成功:
# ```python
# def find_primes(n):
#     """
#     Find all prime numbers between 1 and n.
#
#     Parameters:
#     n (int): The upper limit to search for prime numbers.
#
#     Returns:
#     list: A list of prime numbers between 1 and n.
#     """
#     if n < 2:
#         return []
#
#     is_prime = [True] * (n + 1)
#     is_prime[0], is_prime[1] = False, False
#     primes = []
#
#     for p in range(2, int(n**0.5) + 1):
#         if is_prime[p]:
#             primes.append(p)
#             # Only iterate up to n/p and only mark multiples of primes
#             for i in range(p * p, n + 1, p):
#                 if is_prime[i]:
#                     is_prime[i] = False
#
#     # Collect only prime numbers
#     return primes + [p for p in range(int(n**0.5) + 1, n + 1) if is_prime[p]]
# ```
# 📝 记忆已更新，新增一条 'execution' 记录。
#
# --- 任务完成 ---
# 最终生成的代码:
# ```python
# ```python
# def find_primes(n):
#     """
#     Find all prime numbers between 1 and n.
#
#     Parameters:
#     n (int): The upper limit to search for prime numbers.
#
#     Returns:
#     list: A list of prime numbers between 1 and n.
#     """
#     if n < 2:
#         return []
#
#     is_prime = [True] * (n + 1)
#     is_prime[0], is_prime[1] = False, False
#     primes = []
#
#     for p in range(2, int(n**0.5) + 1):
#         if is_prime[p]:
#             primes.append(p)
#             # Only iterate up to n/p and only mark multiples of primes
#             for i in range(p * p, n + 1, p):
#                 if is_prime[i]:
#                     is_prime[i] = False
#
#     # Collect only prime numbers
#     return primes + [p for p in range(int(n**0.5) + 1, n + 1) if is_prime[p]]
# ```
# ```
